# %%
import json
import random
import pickle
import statistics as stats
import pandas as pd
from nltk.stem import WordNetLemmatizer, SnowballStemmer
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer,TfidfTransformer
from sklearn.svm import SVC,LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.base import TransformerMixin
from sklearn.model_selection import cross_val_score,train_test_split,GridSearchCV
from sklearn.metrics import roc_auc_score,confusion_matrix,accuracy_score,f1_score,precision_score,recall_score,precision_recall_fscore_support,classification_report
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
import seaborn as sns
# %matplotlib inline
stopwords = stopwords.words('english')
import timeit

# %%
with open('../outputs/pickled_results/GNB_RESULTS.pickle' , 'rb') as handle: gnb_results = pickle.load(handle)
with open('../outputs/pickled_results/GNB_CLASS0_RESULTS.pickle' , 'rb') as handle: gnb_class0_results = pickle.load(handle)
with open('../outputs/pickled_results/GNB_CLASS1_RESULTS.pickle' , 'rb') as handle: gnb_class1_results = pickle.load(handle)

with open('../outputs/pickled_results/SVM_RESULTS.pickle' , 'rb') as handle: svm_results = pickle.load(handle)

# %% [markdown]
# ## GNB MIXED

# %% [markdown]
# ### DEV

# %%
plt.figure(figsize=(15,6))
plt.plot(gnb_results['steps'][1:],[stats.mean([i[0][2] for i in step]) for step in gnb_results['results']][1:],label="F1-Score") 
plt.plot(gnb_results['steps'][1:],[stats.mean([i[0][1] for i in step]) for step in gnb_results['results']][1:],label="Recall")   
plt.plot(gnb_results['steps'][1:],[stats.mean([i[0][0] for i in step]) for step in gnb_results['results']][1:],label="Precision")
plt.ylabel('SCORE')
plt.xlabel('NUMBER OF ARTICLES')
plt.legend()
plt.show()

# %% [markdown]
# ### TEST

# %%
plt.figure(figsize=(15,6))
plt.plot(gnb_results['steps'][1:],[stats.mean([i[1][2] for i in step]) for step in gnb_results['results']][1:],label="F1-Score") 
plt.plot(gnb_results['steps'][1:],[stats.mean([i[1][1] for i in step]) for step in gnb_results['results']][1:],label="Recall")   
plt.plot(gnb_results['steps'][1:],[stats.mean([i[1][0] for i in step]) for step in gnb_results['results']][1:],label="Precision")
plt.ylabel('SCORE')
plt.xlabel('NUMBER OF ARTICLES')
plt.legend()
plt.show()

# %% [markdown]
# ## GNB CLASSES

# %% [markdown]
# ### GNB CLASS 0

# %% [markdown]
# #### DEV

# %%
plt.figure(figsize=(15,6))
plt.plot(gnb_class0_results['steps'][1:],[stats.mean([i[0][2] for i in step]) for step in gnb_class0_results['results']][1:],label="F1-Score") 
plt.plot(gnb_class0_results['steps'][1:],[stats.mean([i[0][1] for i in step]) for step in gnb_class0_results['results']][1:],label="Recall")   
plt.plot(gnb_class0_results['steps'][1:],[stats.mean([i[0][0] for i in step]) for step in gnb_class0_results['results']][1:],label="Precision")
plt.ylabel('SCORE')
plt.xlabel('NUMBER OF ARTICLES')
plt.legend()
plt.show()

# %% [markdown]
# #### TEST

# %%
plt.figure(figsize=(15,6))
plt.plot(gnb_class0_results['steps'][1:],[stats.mean([i[1][2] for i in step]) for step in gnb_class0_results['results']][1:],label="F1-Score") 
plt.plot(gnb_class0_results['steps'][1:],[stats.mean([i[1][1] for i in step]) for step in gnb_class0_results['results']][1:],label="Recall")   
plt.plot(gnb_class0_results['steps'][1:],[stats.mean([i[1][0] for i in step]) for step in gnb_class0_results['results']][1:],label="Precision")
plt.ylabel('SCORE')
plt.xlabel('NUMBER OF ARTICLES')
plt.legend()
plt.show()

# %% [markdown]
# ### GNB CLASS 1
# #### DEV

# %%
plt.figure(figsize=(15,6))
plt.plot(gnb_class1_results['steps'][1:],[stats.mean([i[0][2] for i in step]) for step in gnb_class1_results['results']][1:],label="F1-Score") 
plt.plot(gnb_class1_results['steps'][1:],[stats.mean([i[0][1] for i in step]) for step in gnb_class1_results['results']][1:],label="Recall")   
plt.plot(gnb_class1_results['steps'][1:],[stats.mean([i[0][0] for i in step]) for step in gnb_class1_results['results']][1:],label="Precision")
plt.ylabel('SCORE')
plt.xlabel('NUMBER OF ARTICLES')
plt.legend()
plt.show()

# %% [markdown]
# #### TEST

# %%
plt.figure(figsize=(15,6))
plt.plot(gnb_class1_results['steps'][1:],[stats.mean([i[1][2] for i in step]) for step in gnb_class1_results['results']][1:],label="F1-Score") 
plt.plot(gnb_class1_results['steps'][1:],[stats.mean([i[1][1] for i in step]) for step in gnb_class1_results['results']][1:],label="Recall")   
plt.plot(gnb_class1_results['steps'][1:],[stats.mean([i[1][0] for i in step]) for step in gnb_class1_results['results']][1:],label="Precision")
plt.ylabel('SCORE')
plt.xlabel('NUMBER OF ARTICLES')
plt.legend()
plt.show()

# %% [markdown]
# ## SVM MIXED

# %% [markdown]
# ### DEV

# %%
plt.figure(figsize=(15,6))
plt.plot(svm_results['steps'][1:],[stats.mean([i[1][2] for i in step]) for step in svm_results['results']][1:],label="F1-Score") 
plt.plot(svm_results['steps'][1:],[stats.mean([i[1][1] for i in step]) for step in svm_results['results']][1:],label="Recall")   
plt.plot(svm_results['steps'][1:],[stats.mean([i[1][0] for i in step]) for step in svm_results['results']][1:],label="Precision")
plt.ylabel('SCORE')
plt.xlabel('NUMBER OF ARTICLES')
plt.legend()
plt.show()
